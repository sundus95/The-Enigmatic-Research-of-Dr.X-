# %%
from transformers import MarianMTModel, MarianTokenizer
from PyPDF2 import PdfReader

def load_pdf_text(pdf_path):
    """Extracts text content from a PDF file."""
    text = ""
    try:
        with open(pdf_path, 'rb') as pdf_file:
            reader = PdfReader(pdf_file)
            for page_num in range(len(reader.pages)):
                page = reader.pages[page_num]
                text += page.extract_text() + "\n\n"  # Add some separation between pages
    except FileNotFoundError:
        print(f"Error: PDF file not found at {pdf_path}")
        return None
    except Exception as e:
        print(f"An error occurred while reading the PDF: {e}")
        return None
    return text

def translate_chunk(text_chunk, tokenizer, model):
    """Translates a chunk of text."""
    try:
        input_ids = tokenizer.encode(text_chunk, return_tensors="pt", truncation=True, max_length=tokenizer.model_max_length)
        outputs = model.generate(input_ids)
        decoded_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
        return decoded_text
    except Exception as e:
        print(f"Translation error for chunk: {e}")
        return None

if __name__ == "__main__":
    pdf_file_path =  r"C:\Users\salsubhi1\PycharmProjects\Enigmatic Research\Dr.X Files\new-approaches-and-procedures-for-cancer-treatment.pdf"   # Replace with the actual path
    target_language = "ar"
    source_language = "en"
    chunk_size = 400  # Adjust this value based on the model's max length and desired overlap

    model_name = f"Helsinki-NLP/opus-mt-{source_language}-{target_language}"
    try:
        tokenizer = MarianTokenizer.from_pretrained(model_name)
        model = MarianMTModel.from_pretrained(model_name)
        print(f"Loaded model for {source_language} to {target_language}")
    except Exception as e:
        print(f"Error loading model: {e}")
        exit()

    pdf_content = load_pdf_text(pdf_file_path)

    if pdf_content:
        translated_segments = []
        chunks = [pdf_content[i:i + chunk_size] for i in range(0, len(pdf_content), chunk_size)]

        print(f"Translating {len(chunks)} chunks...")

        for i, chunk in enumerate(chunks):
            translated_chunk = translate_chunk(chunk, tokenizer, model)
            if translated_chunk:
                translated_segments.append(translated_chunk)
                print(f"Translated chunk {i+1}/{len(chunks)}")
            else:
                print(f"Failed to translate chunk {i+1}")

        translated_text = "\n".join(translated_segments)

        if translated_text:
            print("\n--- Translated Text ---")
            print(translated_text)

            output_file_path = f"translated_{target_language}.txt"
            with open(output_file_path, "w", encoding="utf-8") as outfile:
                outfile.write(translated_text)
            print(f"\nTranslated text saved to {output_file_path}")
        else:
            print("No text was translated.")
    else:
        print("Could not load PDF content.")
# Out:
# Loaded model for en to ar
# Translating 121 chunks...
# Translated chunk 1/121
# Translated chunk 2/121
# Translated chunk 3/121
# Translated chunk 4/121
# Translated chunk 5/121
# Translated chunk 6/121
# Translated chunk 7/121
# Translated chunk 8/121
# Translated chunk 9/121
# Translated chunk 10/121
# Translated chunk 11/121
# Translated chunk 12/121
# Translated chunk 13/121
# Translated chunk 14/121
# Translated chunk 15/121
# Translated chunk 16/121
# Translated chunk 17/121
# Translated chunk 18/121
# Translated chunk 19/121
# Translated chunk 20/121
# Translated chunk 21/121
# Translated chunk 22/121
# Translated chunk 23/121
# Translated chunk 24/121
# Translated chunk 25/121
# Translated chunk 26/121
# Translated chunk 27/121
# Translated chunk 28/121
# Translated chunk 29/121
# Translated chunk 30/121
# Translated chunk 31/121
# Translated chunk 32/121
# Translated chunk 33/121
# Translated chunk 34/121
# Translated chunk 35/121
# في الآونة الأخيرة، تحسنت كثيرا العديد من المسارات التي تنطوي على تقدم علاج السرطان وكيفية استهدافها، بشكل كبير، مع استراتيجيات متداخلة، تشمل علاجات متعددة مستهدفة أو علاجات كيميائية علاجية متعددة الأهداف أو علاجات كيميائية ”الإشعاعية - الإشعاعية“، مثل الحوانيت ومركبات البلاتينوم، التي تبين أن لها تآزرا في إطار الفقرة 6 من المادة 6 من النهج الجديدة، مثل العقاقير، والجزيئات البيولوجية، والموازنات التي ترشدها المناعية.
# وتُستخدم الفطائر للعلاج حتى وإن لم يصل مستوى العلاج المستثنى إلى مستوى يقاوم معدل الوفيات ويقلل من الوقت الممتد للسرطان الممتد. ويعتمد خلق ثورة جديدة في السرطان الأورامي أو استهداف المخدرات على مسارات وخصائص مختلف كيانات الورم.
# :: نُهج وإجراءات جديدة لعلاج السرطان: المنظورات الحالية: دجينة تولوس ديبيلا 1، سيكي غي موزازو1،2، كيديست ديغامو هيرورو 1، 3، مورين تاياميكا ندالاما 1، بتلهيم ولد الدين ميسيلي1، 4، داغيماوي شيلوت هيلي 1، 5، صوفيا هالايي كيتوي 1، وتسيغاهون مانيازويل1، السرطان النمائي مشكلة صحية عالمية مسؤولة عن وفاة واحدة من كل ست وفيات في العالم.
# لقد كانت نُهج العلاج التقليدية، مثل الجراحة، والعلاج الكيميائي، والعلاج الإشعاعي، قيد الاستخدام، في حين يجري إحراز تقدم كبير في الآونة الأخيرة، بما في ذلك العلاج بالخلايا الجذعية، والعلاج المستهدف، والعلاج بالتسمم، والجسيمات النانوية، والمضاد الطبيعي للأكسدة، والمواد الإشعاعية، والعلاج الكيميائي الدينامي، والعلاج السنودينامي، والعلاج القائم على التسمم الحديدي.
# وقد حقق العلاج بالخلايا المستنبتة فعالية واعدة في إعادة توليد وتصليح الأنسجة المرضية أو التالفة عن طريق استهداف كل من التركيز على السرطان الأوّلي والممتاز على حد سواء، وجلبت الجراثيم النانوية خيارات تشخيصية وعلاجية جديدة.
# وقد ظهر العلاج بالتسمم كإجراء ذو حد أدنى من التوسعية يحرق أو يجمّد السرطانات دون الحاجة إلى جراحة مفتوحة، وأظهرت مضادات الأكسدة الطبيعية إمكانية تتبع الجذور الحرة وتحييد آثارها الضارة، وبالتالي معالجة السرطان أو منعه، ويجري حالياً بحث عدة تكنولوجيات جديدة(ط)
# قدم هذا الاستعراض معلومات مستكملة عن آخر التطورات والإنجازات التي تحققت في مجال علاجات السرطان.
# جامعة أديس أبابا، أديس أبابا، إثيوبيا 2 وحدة بحوث في مجال الأمراض المعوية واللقاحات، مركز بحوث الأمراض المعدية في زامبيا (CIDRZ)، لوساكا، زامبيا، 3 جامعة واشيمو، هوسانا، إثيوبيا 4 جامعة كوتيبي الكبرى، أديس أبابا، إثيوبيا 5 جامعة غوندار، غوندار، إثيوبيا
# "الدراسات المتعلقة بالتطوير والعلاج في أفريقيا، كلية العلوم الصحية، جامعة أديس أبابا، صندوق P.O. Box 9086، أديس أبابا، إثيوبيا، البريد الإلكتروني: dejene.tolosa@aau.edu.et 1034366 SMO 0010.1177/205031211211104366SAGE Open Medication Debela et al.
# )٨( تستخدم العلاجات الهرمونية أيضاً على نطاق واسع في حالات السرطان الخبيثة، وتعتبر كعقبات عضوية لأنها تقيد نمو الورم بالحد من عوامل نمو الهور - العضلية التي تعمل من خلال اتجاه المحور القاعي - النخامي - الغدة الدرقية (HPGA)، وركود المستقبلة الهرمونية، والحد من الغدة الكظرية.
# 9 - في هذا الاستعراض السردي، قُدمت لمحة عامة عن أكثر علاجات السرطان تقدما وابتكارا. وفي الإضافة، يجري حاليا التحقيق في مرحلة البحث أيضا في استراتيجيات جديدة ينبغي أن تطغى على عيوب العلاجات القياسية؛ واستراتيجيات مختلفة لتشخيص السرطان وعلاجه؛ ووضعها الحالي في السياق السريري، مما يؤكد على محاسنها.
# طرائق علاج السرطان يمكننا أن نرى طرائق علاج السرطان بتقسيمها إلى فئات تقليدية (تقليدية) ومتقدمة أو جديدة أو حديثة. وفي هذا العصر العالمي، يركز أكثر من نصف جميع تجارب العلاج الطبي الجارية على علاج السرطان.
# وتتمثل أساليب العلاج التقليدية الأكثر استخداما على نطاق واسع في الجراحة، والعلاج الكيميائي، والعلاج الإشعاعي، في حين تشمل الطرائق الحديثة العلاج بالهرمونات، والعلاجات المضادة للمسببات، وعلاجات الخلايا الجذعية، والعلاج المناعي، والعلاج القائم على الخلية المنجلية.
# 11 - ومن بين هذه الطرائق، تكون الجراحة أكثر فعالية في مرحلة مبكرة من تطور المرض، ويمكن للعلاج الإشعاعي أن يلحق الضرر بالخلايا الصحية والأعضاء والأنسجة، وعلى الرغم من أن العلاج الكيميائي قد أدى إلى خفض معدلات الاعتلال والوفيات، فإن جميع العوامل الكيميائية التي تسبب تقريبا أضرارا بالخلايا الصحية، ولا سيما الخلايا التي تتشقق وتنمو بسرعة.
# ومن هنا، وهي مشكلة رئيسية في العلاج الكيميائي، هي ظاهرة تنمو فيها مقاومة للعقاقير المضادة للسرطان في الخلايا السرطانية التي كبتتها في البداية عقاقير مضادة للسرطان، ويعزى ذلك أساساً إلى انخفاض تناول المخدرات وزيادة انتشارها.
# ومن بين العقبات التي تعترض سبيل السرطان ومقاومة المخدرات ونظمها المعالجة بالدلافين هي المشكلة الأكبر في علاج السرطان والعلامات والأعراض المسببة للتحلل؛ ولكن يوجد حاليا العديد من النهج والعقاقير العلاجية المعتمدة، وتنخفض كفاءة السرطان التقليدي بسبب أمراض الأورام والتشوهات المعمارية للدم الوريدي.
# 15 - وفيما يلي ما يلي: مادة ثيران السرطان المتطورة والمبتكرة - وهي أنواع حشرية بمزاياها وتحدياتها، وخلايا الجراثيم العلاجية للخلايا الجذعية هي خلايا غير متمايزة موجودة في صف سطح العظام (BM) مع القدرة على التفريق في أي نوع من أنواع خلايا الجسم، كما أن الاستراتيجية العلاجية للخلايا الجذعية الجذعية هي أحد خيارات علاج السرطان التي تعتبر مأمونة وفعالة.
# وتُستخدم حالياً الخلايا الجذعية المتوسطة (MSCs) في التجارب التي تُسلَّم من BM، والأنسجة الدهنية، والأنسجة المتشابكة.
# وفي عام 2006، كان اختراع عوامل ياماناكا لحفز الخلايا الجذعية المتعددة القدرات من الخلايا الفيزيائية في إحدى الثقافات بمثابة تطور في بيولوجيا الخلايا.
# وفي الوقت الراهن، لا يمكن لهذه الخلايا، الموجودة في ب.م، أن تشكل جميع خلايا الدم الناضجة في الجسم إلا بموافقة الأغذية.
# وتشتمل 20 حالة مرضية على العديد من الأنسجة والأعضاء، والأدوار الهامة في إصلاح الأنسجة وتجديدها في الخلايا، مثل أوستيوكيت، وديبوكريات، وكوندروكيتيات. وتتمتع هذه الحالات بخصائص بيولوجية خاصة وتستخدم كمكملة لنهج أخرى في معالجة التومو.
# 21 (Rs. 21 NSCs) يمكنها أن تجدد نفسها وتولد خلايا عصبية وخلايا جليلية جديدة وتستخدم لمعالجة كل من الثدي الأوّلي والثدي الاستوائي وغيره من الأورام. وهناك 22 خلية من خلايا السرطان الجذعية الجذعية المسببة للسرطان تتولد في الخلايا الجذعية العادية أو السلائف/الخلايا المولدة من خلال عملية الطفرات الجينية.
# 23 خلية ستيم لديها العديد من آليات العمل في معالجة الورم. العملية Homing Dipela et al. 3 هي إحدى الآليات التي هي هجرة سريعة من HSCs إلى منافذ الخلايا الجذعية المحددة في BM بعد أن تخضع عمليات الزرع لعملية التملق قبل أن تؤدي إلى ظهور خلايا الدم المتخصصة. تعتمد هذه الآلية على التفاعل النشط على رهان التفاعل النشط.
# (22) الآلية الثانية هي التأثير الورمي - المداري الذي يحدث فيه هجرة الشركات البحرية الدولية نحو البيئة الدقيقة للورم (TM) بعد أن تجتذبها CXCL16، SDF-1، CCL-25، وIL-6 التي تفرزها خلايا الورم واخصائيات عفريت MSCs داخلها.
# (24) تعمل خلايا السترات أيضاً عن طريق إفراز عامل باراكرين، بما في ذلك الخصيات الخارجة عن الخلية والمواد القابلة للذوبان، (25) وقدرة تفاضلية هذه الخلايا، مثل HSCs التي تم زرعها، يمكن أن تؤدي إلى جميع أنواع خلايا الدم. (26) وعموماً، يمكن أن يؤدي علاج السرطان باستخدام علاج الخلايا الجذعية باستراتيجيات مختلفة، بما في ذلك زرع HSC.
# وواجه نهج علاج الخلايا الجذعية القادرة على معالجة الخلايا الجذعية الآثار الجانبية التالية: (1) الورم، (2) الأحداث المعاكسة في عملية زرع HSC، (3) سمية المخدرات ومقاومة المخدرات، (4) زيادة الاستجابات المناعية والحصانة الذاتية، (5) العدوى الفيروسية.
# وبالإضافة إلى ذلك، فإن النتائج الحالية من تكنولوجيات الخلايا الجذعية مشجعة للغاية لعلاج الأورام ولكنها لا تزال بحاجة إلى بذل المزيد من الجهود لتحسين السلامة والفعالية قبل أن تتمكن من الدخول في التجارب السريرية.
# إن علاجات السرطان المستهدَفة المستهدَفة المستهدَفة بالعقاقير هي العقاقير أو المواد الأخرى التي تُستخدَم أحياناً كـ "عقاقير موجَّهة بشكل مجزأ"، و"علاجات موجَّهة بشكل مجزأ"، و"أدوية مُخَلَّصة الهدف"، و"أدوية مُخْتَلِفَة". وتتمثل آلية عمل هذه العقاقير في التدخل في جزيئات النمو التي تؤدي إلى إعاقة نمو وانتشار السرطان.
# أو يتم تحديد البدء والتدرج بواسطة TM من ورم غير نمطي يتألف من خلايا الظهارة الظهارية، والخلايا الظهارية، وخلايا العضلات السلسة، والخلايا التليفية، ومختلف الخلايا التهابية، وخلايا الإندريت، وخلايا CSCs. وهناك العديد من آليات ومسارات الإشارة التي تتفاعل خلايا تشكيل T-M تفاعلاً دينامياً مع الخلايا السرطانية التي تكون مناسبة لاستدامة
# لذا فإن هذه المشاكل تتداخل مع الآليات الخلوية، مثل احتجاز دورة الخلايا، واستثارة إفرازات الإسهاب، والانتشار قبل الإختراق، والتداخل في الذكاء.
# 36 تعديل TM واستهداف TM لإيصال الأدوية من أجل العلاج الفعال هما استراتيجيتان يمكن استخدامهما لمعالجة السرطان(37). وتعمل عقاقير العلاج المستهدَفة بطرق مختلفة عن طرق العلاج الكيميائي العادي لمعالجة عقاقير مثل التصدي لخلايا السرطان مع القيام في الوقت نفسه بقدر أقل من الضرر للخلايا العادية التي هي برنامج يحدد t
# 38 - أدى استخدام العلاج المستهدف إلى زيادة ملحوظة في معدل البقاء على قيد الحياة بالنسبة لبعض الأمراض، على سبيل المثال، من 17 في المائة إلى 24 في المائة في المرضى المصابين بسرطان البنكرياس المتطور، وإضافة الأرلوتين إلى العلاج الكيميائي المعياري. وكان لماتينيب تأثير درامي على اللوكيميا النخاعية المزمنة، والتريتوكسيماب، والسنتينيب، وتراستوزوماب قد أحدث ثورة في علاج الكلى.
# 39) يمكننا تصنيف عوامل الخلية المستهدفة استناداً إلى آلية عملها أو موقعها المستهدف، وبعض الانزيمات تعمل كمؤشرات لزراعة الخلايا السرطانية، وبعضها يستهدف الطحالب - تمنع الانزيمات التي هي إشارات لزراعة الخلايا السرطانية. هذه العقاقير تسمى مثبطات إنزيم. منع إشارات الخلايا هذه يمكن أن يمنع السرطان من الكبر.
# (40) بعض العلاجات المستهدفة تسمى عقاقير مسببة للتسمم لأنها موجهة مباشرة إلى أجزاء الخلية التي تتحكم في ما إذا كانت الخلايا حية أم ميتة. ومن الأمثلة على ذلك: Serine/threonine Qinase، والبروتين Cinase B (PKB/Akt)، التي تدعم بقاء الخلية، ومثبطات هذا البروتين هي في المرحلة ما قبل السريرية.
# تساعد ich على قطع إمدادات دم الأورام بحيث لا يمكن للأورام أن تنمو. فضلاً عن ذلك، فإنها توقف نمو الورم الذي ينطوي على تقليص إمدادات الدم للورم عن طريق منع العوامل المسببة للتشوهات، مثل عامل نمو الأوعية الدموية أو مستقبلاته (EGF) أو مستقبلاته. وقد أظهرت الدراسة بقاء المرضى المصابين بسرطانات ملونة متقدمة على قيد الحياة.
# ISG(SISC) (SISC) (Sipuelusel-T)
# أنواع العوامل المستهدفة مونوكلونال المضادة للأجسام المضادة للأجسام المضادة للعقاقير هي إصدارات من صنع الإنسان لبروتينات النظام المناعي التي تُدار عن طريق الحقن الوريدي لمهاجمة بعض القطران - تحصل على خلايا سرطانية، وهي تحتوي على نسبة أكبر من المكونات البشرية من مكونات المطهر.
# (هـ) تعيين وظائف مناعة مضيفة لمهاجمة الخلية المستهدفة، تكون ملزمة بليغاند أو مستقبلات، وبالتالي توقف العمليات الأساسية للخلية السرطانية، وتحمل حمولة فتاكة، مثل النظائر المشعة أو التكسينات، إلى الخلية المستهدفة.(44) Gemtuzumab مثال على جسم مضاد أحادي الكلونة محدد CD-33 يستخدم حاليا لمعالجة مكافحة غسل الأموال عن طريق المزاوجة مع كاليشياميسين.
# وهناك أيضاً استخدام آخر للعوامل المستهدفة للأجسام المضادة الأحادية الكلونية(47). 47 مثبطات جزيئية صغيرة هذه بروتين أصغر حجماً (2500 Da) من البروتينات المضادة الأحادية الأُحادية الأُحادية الكلورة، بحيث يمكنها ببساطة الانتقال عبر أغشية البلازما من خلال أغشية البلازما.
# وتكمن مرحاتها الرئيسية في مقاطعة العمليات الخلوية عن طريق التدخل في الإشارات الخلوية داخل الخلايا لـ tyrosine Cinases التي تؤدي إلى تثبيط إشارة وتشفير tyrosine Qinase، وتدشين سلسلة تعاقبية مشقو-ضوئية يمكن أن تؤدي إلى تثبيط نمو الخلية، وتكاثر الانتشار، والهجرة، والتشوهات في الأنسجة الخبيثة. 48 أمثلة على مثبطات جزيئية صغيرة(أ)
# وهناك أيضا اللفاتينيب وسورافينيب اللتان تعملان على تثبيط تثبيط ERGFR/Erb-B2 المستقبِل Tyrosine Qinase 2 (ERBB2) بالنسبة لـ ERBB2- الإيجابية الإيجابية من مرض الثدي و VEGFR Cinase، في سرطان الكل.
# الهنديات التي تدمر أوراماً مع إزالة منها غالباً ما تشير إلى الأورام الصغيرة الحجم التي تقل عن 3 سم والخيار الجراحي غير مسموح به. يتم استخدام التحلل أيضاً مع تثبيط الأورام الأكبر. ولكن قد لا يتم الإشارة إلى هذه التقنية لمعالجة الأورام بالقرب من الأوعية الدموية الرئيسية، أو الحجاب الحاجز، أو قنوات البللة الرئيسية بسبب تدمير بعض الأنسجة الطبيعية حول الورم.
# 50 درجة حرارة حرارية: تستخدم هذه التقنية فرطاً مفرطاً في الحرارة أو انخفاضاً في درجة الحرارة لتدمير أنسجة ورم تركز على منطقة محورية في الورم وحوله. وعلى غرار العملية الجراحية، يزيل التسمم الحراري الورم وهامشاً سميكاً يتراوح بين 5 و10 مم من الأنسجة الطبيعية البدائية - غير أن النسيج يقتل في الموقع ثم يمتصه الجسم لاحقاً.
# إن نوع الورم، والموقع، واختيار الطبيب، والحالة الصحية هو الذي يحدد هذا النهج. 51 التحلل في الترددات الراديوية، والتضخم في الموجات الدقيقة، والموجات فوق الصوتية التي تركز على درجة عالية من الكثافة، والتبريد، يتم استخدامها بشكل مُسْتَدْعِل في البيئة السريرية.
# وتعمل جميع هذه العلاجات على أساس مبدأ فرط الحرارة باستثناء التكرير. ومن بين جميع تقنيات التحلل، أظهر التكرير أعلى قدرة على الحصول على استجابة مناعية لاحقة للتحلل. وأظهرت 52 دراسة حديثة إضافة إلى اختلال الأنسجة RFA، ويمكن للتبريد أن يُعَدِّل جهاز المناعة الذي طُبقت عليه.
# وقد بينت الأدلة أن إجراءات التسمم تؤثر على السرطان بسبب استجابته الالتهابية المحلية مما يؤدي إلى وجود جين مناعي المصدر.(53) وميزة هذا الإجراء على العملية الجراحية هي أنه يوفر نهجاً أدنى (مثلاً، عن طريق الفم أو عن طريق الفم أو عن طريق التنظير) أو نهجاً غير متعثِّر لعلاج السرطان ويحصل على استنشاق كبديل.
# 54 - إن عملية التكرير في مجال التكرير هي إحدى تقنيات التحلل التي تؤدي إلى تفتيت الأنسجة الواسعة بالتجميد في درجات الحرارة الفتاكة التي تُبطن بالسوائل، مما يتسبب في نشوء أنسجة واسعة النطاق. ويعالج هذا العلاج الأورام البينية والخبيثة في معظم الأحيان.
# وقد اقترح التبريد كخيار علاجي جذاب وعزز بقاء المريض. وتستند 56 تقنية للتبريد إلى مبدأ تأثير جول - تومسون الذي درسه العديد من الباحثين في الثلاثينيات وتوصلوا إلى نتيجة لنا.
# غير أنه بعد عام 1950، استعاض ألنغتون عن السائل N2 لمعالجة مختلف اضطرابات الآفات الجلدية(47).
# (التيارات الكهربائية العالية التردد) ظروف تدمير الخلايا السرطانية - تصوير التكنولوجيا - الخواص، مثل الموجات فوق الصوتية، أو التصوير المقطعي المحسوب (CT)، أو التصوير الرنين المغنطيسي (MRI)، أو توجيه أقطاب الإبر (Debela et al. 5) في خلية الورم، وعموماً، فإن "RFA" هو النهج الأكثر فعالية لمعالجة الأورام الصغيرة الحجم التي يقل قطرها عن 3 سنتيمترات.
# 57 - خيارات علاج السرطان النووي: بعد البدء في استخدام الأجهزة القابلة للنشر أو النظم الكهربائية المتعددة، يمكن لـ RFA أن تعالج أوراما متوسطة (حتى 5 سم قطرها). و 58 علاجا جينيا للعلاج هو إدخال نسخة عادية من جين معطوب في الجينوم لعلاج اضطراب معين. ويرجع أول تطبيق إلى عام 1990 عندما استُغلت ناقل مضاد للفيروسات العكوسة في إيصال نزعات الأدينوسين.
# (ADA) جين لخلايا T في المرضى الذين يعانون من نقص حاد في المناعة البشرية (SCID) - يجري حالياً حالياً حوالي 000 2 علاج للجينات، وثلثاها متصلان بالسرطان، واستراتيجيات مثل التعبير عن الجينات المحفزة للبروابوتونيك والحساسية الكيميائية، والتعبير عن الجينات المضغوطة للورم البري النوع، والتعبير عن الجينات القادرة على التماس استجابات محددة مناعة مضادة للآذان،
# ويجري تقييم عملية إيصال الجينات (47 thymidine Cinase) (TK) بفعالية من أجل إدارة الجينات الموالية للعقاقير (ganciclovir) لتفعيل إفرازها وحفز سمية سيتوسمية معينة.(59) وقد تم تقييم الجينات المضغوطة للورم P53 الذي يحمله الناقلات لأغراض إكلينيكية مؤخراً جداً.
# 60 - كان لسرطان الخلية المائية في الرأس والرقبة نجاح مماثل عند اقترانه بالعلاج الإشعاعي. وتتمثل بعض التحديات التي واجهت العلاج بالجينات في اختيار الظروف المناسبة واختياره. وتتمثل بعض التحديات التي واجهت العلاج بالجينات في اختيار الظروف المناسبة واختيار ما يلي:
# وقد استخدمت البحوث الأساسية والترجمة الطبية تدخل RNA (RNAi) كتكنولوجيا فعالة قادرة على إنتاج جينات مستهدفة متكتمة.
# (63) يمكن تصميم أي من هذه المنظومات لحجب الأهداف المرغوبة، بما في ذلك انتشار الخلايا والغزو الاستقلابي؛ ومن ثم، فإن الميشا - النمسات الجزيئية الدقيقة تشكل عاملاً مساعداً على تكوين الورم.
# (هـ) أو 64 أو 65 أو سرطان الجينات المتحورة (أي K-RAS).(66).
# )أ( فوسفوروثيوات عند نهاية ٣ ' ، وإدخال مجموعة ميثيل ٢ ' O ' ، وتعديلها ب ٢,٤ - دينيتروفينول( ومغلفة دهنية، أو الاقتران مع جزيئات عضوية )بوليمرات، سبتيدات، شحوم، مضادات للسود، جزيئات صغيرة( تستهدف بكفاءة أن تعبر تلقائيا أغشية الخلايا الموجودة في المناطق النووية المجردة.
# (70) يمكن أن تتكون من 2 - ثنائيو - ثنائي أويل - 3 - ثلاثي ميثيل أمونيوم بروبان (DOTAP) و N-[1-(2-3-DEoloyloyloxy)propyl]-N، Nتري ميثيل أمونيوم ميثيل كبريتات الميثيل (DOTMA).(71) في الوقت الراهن، تتمثل تجربة سريرية في المرحلة الأولى في تعيين مرضى لتقييم سلامة مستقبلات إيف A2 (EphA2) التي تستهدف 2 1 - ثنائي أويل - سن - غليسيرو - 3 - فوسوكولين (DOPC) مغلفة بـ SIRNA
# (SyRNAA-EphA2-DOPC) في المرضى الذين يعانون من سرطان الإيجار المتقدّم والتكرار. ويمكن تركيز 72 من هذه البارافينات في الميرات المتعددة متعددة البوليات الكيسيكية، مثل الشيتوسان، والكلورديكسترين، والبولي إثيلينينين (PI). 73 CALAA-01 هو واحد من البوليمرات السيكلودكسترين المدمجة مع المحول البشري يجري إدخاله في المرحلة الأولى من التجربة السريرية. وقد استُخدم PEI كمضاد للسرطان من خلال تشكيل جسيمات نانوية صغيرة وتحميل صغيرة.
# (74) بدأت التجربة السريرية للمرحلة الثانية لتقييم الجرعة المحلية EluterR (SiG12D LODER) الموجهة إلى أونكوجين (K-RAS) المتحولة لكريستين كيرستن ساركوما الجرذان (K-RAS) لعلاج سرطان البنكرياس المتطور.
# 75 - أدى إدخال المناقصات النانوية إلى تحسن كبير في استقرار المناطق الريفية البحرية، والبارا - المساحيق، وخواص التوزيع البيولوجي، والاستهداف، والأغراض المحددة.
# وفي المستقبل، يتمثل البحث المطلوب في إنشاء أفضل المعطيات الشخصية - apy وصوب الإطلاق المراقب للوصول إلى قطران محدد فقط - في معالجة الورم. ويلخص الجدول 2 عقاقير العلاج الجيني استناداً إلى آلية عملها واستثارتها.
# وهذه الجزيئات، مثل الأشعة فوق البنفسجية، والتلوث، ودخان التبغ، التي تنتهي إلى تجميع الأنواع التفاعلية، ولا سيما الأوكسجين، والمتطرفات الحرة، مسؤولة عن ظهور العديد من الأمراض، إلى جانب السرطان. بل إن هذه الجزيئات يمكن أن تكون نتيجة للعلاج السريري للأدوية؛ ولكن كيف يتم خلقها بشكل طبيعي إضافي داخل خلايانا وأنسجتنا بواسطة الميتوكوندري.
# (أ) إجهاد أكسيدي للدواء المفتوح وأنواع أوكسجين جذرية يمكن أن يشيرا - يمكن أن يغيرا - يمكن أن يغيرا - تنظيم عوامل التناسخ عن طريق سد شيخوخة الحمض الخلوي الصبغي (DNA) وغيره من العُضَل الأحيائي (Ma-kro-gro-gule).(77) فيتامينات، والبوليفينولات، والكونات النشطة الأحيائية المستمدة من النباتات هي من المواد المضادة للأكسدة الطبيعية المستخدمة كسابقات.
# ومن الأمثلة على المواد المضادة للأكسدة الطبيعية التي تم فحصها في v.
# هيرو و ifivo. 79 التوافر البيولوجي المحدود و/أو السمية المحدودة هي واحدة من الألغاز الشائكة للعقاقير الطبيعية في حين ترجمتها إلى ممارسة سريرية.(47) لكوركونين تأثيرات سمية سيولوجية في أنواع مختلفة من الأورام، مثل الدماغ، والرئتين، واللوكيميا، والبنككرياتيك، والسرطان الخلوي الكبدي، 80 بينما تُوفر الخلايا العادية بجرعات علاجية فعالة.
# ويجري دراسة مدة الطعام وجرعات علاجية تتسم بالكفاءة(80). وفي هذا اليوم، أجريت حوالي 27 تجربة سريرية، بينما تجري دراسة 40 تجربة على الكركونين. البربيرين مركب من مركب الكلاويد الذي دُرس ليكون فعالاً ضد مختلف أنواع السرطان بوصفه عاملاً كيميائياً مانعاً للوقاية، يغير العديد من مسارات الإشارة. وقد وُضعت استراتيجيات تقنية نانوية مختلفة لتسخير دليفته.
# (81) هناك ست تجارب سريرية قيد الدراسة واثنتان تم استكمالهما. واليرسيتين هو عامل آخر من عوامل منشأ النباتات الطبيعية يكون فعالاً بمفرده وأيضاً بالاقتران مع عوامل العلاج الكيميائي في معالجة العديد من أنواع السرطان، مثل الرئتين، والبروستات، والكبد، والقولون، وسرطانات الثدي.
# 83 - يجري حاليا دراسة ست تجارب سريرية واكتملت سبع دراسات. التجارب السريرية الحالية في السنوات الأخيرة، اتخذ تحليل أدوية السرطان خطوات ثابتة نحو مزيد من العلاجات العملية والدقيقة والأقل عددا من علاجات السرطان الغازية في بحوث التجارب السريرية (الشكل 1).
# وتتضمن المدخلات التي تركز على علاجات السرطان في قاعدة بيانات التجارب السريرية (www.clinicalTri-als.gov) مصطلحات الخلية الجذعية، والحرف المستهدَف - aby، والعلاج المناعي، والعلاج الجيني لأنها واعدة وفعالة جداً. ويلخص الجدول 3 مزايا ومساوئ النُهج العلاجية الجديدة.
# وتركز الأساليب الحالية في علم الأورام على تطوير أساليب مأمونة وكفؤة للسرطان النانوية - ساعدت الرعاية الطبية المستهدفة على زيادة التوزيع البيولوجي للعوامل الكيميائية العلاجية الحديثة أو التي تم اختبارها بالفعل حول الأنسجة المحددة التي يتعين معالجتها؛ وطرق مختلفة، مثل الرعاية الطبية المتسلسلة، وتوصيل العلاج، والإعاقة.
# (22) على العكس من ذلك، يمكن استخدام الخلايا الجذعية كعلاج متجدد، وناقلات علاجية، واستهداف للعقاقير، وتوليد خلايا مناعية بسبب وجود أعمال بيولوجية فريدة من نوعها في خلايا أخرى. (22) وفي المقابل، يمكن استخدام الخلايا الجذعية كأدوية متجددة، وناقلات علاجية، واستهداف للعقاقير، وتوليد خلايا مناعية بسبب وجود أعمال بيولوجية فريدة في الخلايا الأخرى.
# وأخيراً، فإن نُهُج العلاج بالإشعاعات والاعتلالات تيسر إدارة مجموعات المعارف الضخمة من مرضى السرطان من أجل تعزيز التكهنات والنتائج. ولقد أُحرز قدر كبير من التقدم، ولكن من المرجح أن يأتي الكثيرون آخرون قريباً، مما من شأنه أن ينتج المزيد والمزيد من الجداول المخصصة.
# الدالة 01 المعالجة البنفسجيةحلية على الماء (OV) تحلل خلايا الورم وتُدخل جينات كبت الورم البري النوع في الخلايا التي تحدث بصورة طبيعية أو التي يتم تعديلها جينياً
# SB-ce
# (ج) الحالة الراهنة للتجارب السريرية لاستراتيجيات علاج السرطان المبتكرة والمبتكرة. الجدول 3 - مقارنة بين مزايا وعيوب العلاجات الجديدة للسرطان. S. S. no.
# يمكن الجمع بين العلاج المأمون والفعال في الخلايا الستم والعلاج المأمون والفعال إلى جانب استراتيجيات أخرى
# (ب) زيادة فرص إبطال مفعولها(ب)
# الحاجة إلى إعداد الجرعات والشروط المناسبة للإطلاق المراقب (RNAI)(05) مضادات الأكسدة الطبيعية المتاحة بسهولة بكميات كبيرة
# نُظُم الرعاية الصحية، س. ن. ن. أنواع نظام تقديم العلاج
# ويشكر المؤلفان مركز تطوير العقاقير المبتكرة والتجارب العلاجية لأفريقيا، جامعة أديس أبابا، على الدعم المقدم.
# وقد أعلن المؤلف (المؤلفون) عدم وجود تضارب محتمل في المصالح فيما يتعلق بالبحث و/أو تأليف و/أو نشر هذه المادة.
# ORCID IDs Déjene Toluse Dipela https://orcid.org/0000-0002-4615-5839 Tsegahun Maniazeual https://orcid.org/0000-00-0000-0002-8360-7574 المراجع 1. سونغ H, Ferlay J, Siegel RL, et al.
# م. م. م. م. م. م. ٢٠٢١؛ ٢٧: ٣٤-٤٤. ٣ - ميريل SWD, Ingle SM, May MT, et al.
# معدل وفيات ومضاعفات في مرحلة ما بعد الجراحة السرطانية: دراسة جماعية مرتقبة متعددة المراكز في 82 بلداً. Lancet 2021; 397: 387 - 397. 5. روي أ ولي SD. تعديل الورم باستخدام علاجات الجراثيم النانوية. Weley Interdiscep Rev nanomed Nanobiotechnoll 2016; 8 (6): 891-908. 6 Bayat Moceri R, Homayouni TS, Baluch N, et al.
# 7 - عباس ز وراهمان س. لمحة عامة عن طرائق علاج السرطان: Neoplasm 2018؛ 1: 139-157. 8. أل حسين أ، مانوتو SL، أومبيندا - ليمومبا S، وآخرون، استعراض للعلاج الكيميائي والعلاج الدينامي الضوئي لعلاج سرطان الرئة. مضادات السرطان وكلاء Med Chem 2021؛ 21 (2): 149-161. 9. Ghanghoria R, Kesharwani P, Tekade RK, et al.
# (ج) السرطانات 2019؛ 11: 11: 11. 11. آرويبو M, Vilaboa N, Saiez-Guterez B, et al. تقييم تطور علاج السرطان.
# تقدم ميدان تسليم المخدرات: التركيز على السرطان. خلية السرطان 2003؛ 4 (5): 337-341. 13. شابيرا أ، ليفني YD، بروكسترمان هـ. ج.، وآخرون، طب النانو للعلاج السرطاني المستهدف: نحو التغلب على مقاومة العقاقير. Resist Udat 2011؛ 14 (3): 150-163. 14. موندال ج، بانيغراهي AK، خودا - بوخش Ar.
# (ج) نانوماتر 2019؛ 2019: 919: 492712. 16. ناجي أ، إيتوكو م، فافير ب، وآخرون، الوظائف البيولوجية للخلايا الجذعية المتوسطة النطاق والآثار السريرية.
َّةٌ مُعَلَّةٌ مُعَلِنْمْنْنَةٌ مِنَةٌ مِنَعَةٌ مِنَةٌ مِنَةٌ مِنَةٌ مِنَةٌ مِنَةٌ مَةٌ مِنْعَةٌ مِنْعَى مِنَةٌ مَةٌ مِنَةٌ مِنْ وَةٌ مِنْ وَعْهْهْهْهْهْهْكَةٌ مِنَةٌ مَةٌ مَةٌ مَةٌ مِنَةٌ مَةٌ مَةٌ مِنْكُوْهْهْكَعْهْهْهْكَةٌ مِنَةٌ مِيْهْكَةٌ مِنَةٌ مِنْكَةٌ مَةٌ مَةٌ مِيْكَةٌ مِنَلَةٌ مَةٌ مَةٌ مَةٌ مِنْكَةٌ مِنَةٌ مِنْهْهْكَلَلَا
# RNA - التدخل الناتج عن التعارض الناجع في النواة، أو التأثير غير المستهدف، أو التأثير خارج الهدف، أو الأدجفانت المناعي؟ جبهة إممونول 2017؛ 8.8: 331.69 Xu CF و Wang J.
# HS, Song IHH, Song IH, Kim JC, et al.
# (ج) إطلاقات المراقبة 2006؛ 115: 234-241. 72. فاغنر MJ, Metra R, McArthur MJ, et al.
# الاستهداف الجيني الوسيط RNAi من خلال التطبيق المنهجي لـ SIRNA المركب المتعدد الإيثيل - ثنائي نيمين (PEI) - SIRNA في الجسم الحي؛ 12 (5): 461-466. 75 Jeong JH, Mok H, OOH YK, et al. SIRNA conjug Chem 2009؛ 20 (1): 5 - 14. 76 أندريوززي P, Diamanti E, Py-Daniel KR, et al.
# ACCS Appl Mater conspaces 2017; 9:3842-38254.77 Halliw B. Oxididative الإجهاد والسرطان: هل انتقلنا للجناح؟ Biochem J 2007؛ 401: 1-11.78 برنارديني S, Teeezzi A, Lageza Masci V, et al. المنتجات الطبيعية للصحة البشرية: لمحة تاريخية عن نهج اكتشاف المخدرات. Nat Prod Res 2018; 32(16): 1926-1950. 79 شيكارا S, Nagaparshan.
# LD, Singhaal J, et al et al. Oxiddative and Femical كيميائيات فيزيائية غذائية: دور في دور السرطان في مرحلة ما قبل العلاج والمعالجة. Lett 2018؛ 413: 122-13. 80: Imran M, Ullalah A, Ahedaed F, et al. Kucurmin, مضادات السرطان والمنظورات المضادة للسموم: استعراض شامل. Crit Rev Food Sci Nutr 2018؛ 58: 1271-1293.81 Farooqi AAA, kreshi MZ, Kald S, et al. et al.
# (أ) البحث عن أجزاء مفقودة من أحجية ناقصة لمعالجة فعالة للسرطان. السرطانات 2019؛ 11: 478. 82 ليو ي، تانغ زغ، لين ي، وما إلى ذلك من آثار الكورسيتين على انتشار النبتة، واستيعاب وهجرة الخلايا البشرية glioblastoma U251. Biomed Pharmacond 2017؛ 92: 33–38. 83 يانغ ف، سونغ ل، وانغ هـ، وآخرون في سرطان البروستاتا: العلاج الكيميائي والكيمياوي.
# 84 - وانغ هـ، و هـي، و هـي. نانوبرات من أجل إيصال المخدرات المستهدفة إلى الخلايا الجذعية والورم السرطانيين. أساليب Mol Biol 2018؛ 1831: 59-67. 85. Thaw Z, Zheng L, Chen W, et al. واستراتيجيات إيصال العلاج المناعي للسرطان: أوجه التقدم الحديثة والمنظورات المستقبلية. J Hemattol Oncol 2019; 12.12.
# 86 - سونغ YK وكيم SW. التقدم المحرز مؤخرا في تطوير نظم إيصال الجينات، Biomater Res 2019; 23: 8.87.Vaiserman A, Colliada A, Zayachkivska A, et al.
#
# Translated text saved to translated_ar.txt

# %%
from transformers import MarianMTModel, MarianTokenizer
from PyPDF2 import PdfReader
from nltk.tokenize import sent_tokenize
import nltk 
nltk.download('punkt_tab')

def load_pdf_text(pdf_path):
    text = ""
    try:
        with open(pdf_path, 'rb') as pdf_file:
            reader = PdfReader(pdf_file)
            for page_num in range(len(reader.pages)):
                page = reader.pages[page_num]
                text += page.extract_text() + "\n\n"
    except FileNotFoundError:
        print(f"Error: PDF file not found.")
        return None
    except Exception as e:
        print(f"Error reading PDF: {e}")
        return None
    return text

def load_pdf_text_into_sentences(pdf_path):
    full_text = load_pdf_text(pdf_path)
    if full_text:
        sentences = sent_tokenize(full_text)
        return sentences
    return []

def translate_chunk(text_chunk, tokenizer, model):
    try:
        input_ids = tokenizer.encode(text_chunk, return_tensors="pt", truncation=True, max_length=tokenizer.model_max_length)
        outputs = model.generate(input_ids)
        decoded_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
        return decoded_text
    except Exception as e:
        print(f"Translation error for chunk: {e}")
        return None

if __name__ == "__main__":
    pdf_file_path = r"C:\Users\salsubhi1\PycharmProjects\Enigmatic Research\Dr.X Files\new-approaches-and-procedures-for-cancer-treatment.pdf"
    target_language = "ar"
    source_language = "en"
    output_file_path = "translated_document_full.txt"

    try:
        tokenizer = MarianTokenizer.from_pretrained(f"Helsinki-NLP/opus-mt-{source_language}-{target_language}")
        model = MarianMTModel.from_pretrained(f"Helsinki-NLP/opus-mt-{source_language}-{target_language}")
        print(f"Loaded model for {source_language} to {target_language}")
    except Exception as e:
        print(f"Error loading model: {e}")
        exit()

    original_text = load_pdf_text(pdf_file_path)

    if original_text:
        with open(output_file_path, "w", encoding="utf-8") as outfile:
            outfile.write("--- Original PDF Content ---\n")
            outfile.write(original_text)
            outfile.write("\n\n--- Translated PDF Content ---\n")

            sentences = sent_tokenize(original_text)
            translated_sentences = []
            for i, sentence in enumerate(sentences):
                translated_sentence = translate_chunk(sentence, tokenizer, model)
                if translated_sentence:
                    translated_sentences.append(translated_sentence)
                    print(f"Translated sentence {i+1}/{len(sentences)}")
                else:
                    print(f"Failed to translate sentence {i+1}")

            translated_text = " ".join(translated_sentences)
            outfile.write(translated_text)
            print(f"\nOriginal and translated content saved to {output_file_path}")

    else:
        print("Could not load PDF content.")
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\salsubhi1\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# Loaded model for en to ar
# Translated sentence 1/532
# Translated sentence 2/532
# Translated sentence 3/532
# Translated sentence 4/532
# Translated sentence 5/532
# Translated sentence 6/532
# Translated sentence 7/532
# Translated sentence 8/532
# Translated sentence 9/532
# Translated sentence 10/532
# Translated sentence 11/532
# Translated sentence 12/532
# Translated sentence 13/532
# Translated sentence 14/532
# Translated sentence 15/532
# Translated sentence 16/532
# Translated sentence 17/532
# Translated sentence 18/532
# Translated sentence 19/532
# Translated sentence 20/532
# Translated sentence 21/532
# Translated sentence 22/532
# Translated sentence 23/532
# Translated sentence 24/532
# Translated sentence 416/532
# Translated sentence 417/532
# Translated sentence 418/532
# Translated sentence 419/532
# Translated sentence 420/532
# Translated sentence 421/532
# Translated sentence 422/532
# Translated sentence 423/532
# Translated sentence 424/532
# Translated sentence 425/532
# Translated sentence 426/532
# Translated sentence 427/532
# Translated sentence 428/532
# Translated sentence 429/532
# Translated sentence 430/532
# Translated sentence 431/532
# Translated sentence 432/532
# Translated sentence 433/532
# Translated sentence 434/532
# Translated sentence 435/532
# Translated sentence 436/532
# Translated sentence 437/532
# Translated sentence 438/532
# Translated sentence 439/532
# Translated sentence 440/532
# Translated sentence 441/532
# Translated sentence 442/532
# Translated sentence 443/532
# Translated sentence 444/532
# Translated sentence 445/532
# Translated sentence 446/532
# Translated sentence 447/532
# Translated sentence 448/532
# Translated sentence 449/532
# Translated sentence 450/532
# Translated sentence 451/532
# Translated sentence 452/532
# Translated sentence 453/532
# Translated sentence 454/532
# Translated sentence 455/532
# Translated sentence 456/532
# Translated sentence 457/532
# Translated sentence 458/532
# Translated sentence 459/532
# Translated sentence 460/532
# Translated sentence 461/532
# Translated sentence 462/532
# Translated sentence 463/532
# Translated sentence 464/532
# Translated sentence 465/532
# Translated sentence 466/532
# Translated sentence 467/532
# Translated sentence 468/532
# Translated sentence 469/532
# Translated sentence 470/532
# Translated sentence 471/532
# Translated sentence 472/532
# Translated sentence 473/532
# Translated sentence 474/532
# Translated sentence 475/532
# Translated sentence 476/532
# Translated sentence 477/532
# Translated sentence 478/532
# Translated sentence 479/532
# Translated sentence 480/532
# Translated sentence 481/532
# Translated sentence 482/532
# Translated sentence 483/532
# Translated sentence 484/532
# Translated sentence 485/532
# Translated sentence 486/532
# Translated sentence 487/532
# Translated sentence 488/532
# Translated sentence 489/532
# Translated sentence 490/532
# Translated sentence 491/532
# Translated sentence 492/532
# Translated sentence 493/532
# Translated sentence 494/532
# Translated sentence 495/532
# Translated sentence 496/532
# Translated sentence 497/532
# Translated sentence 498/532
# Translated sentence 499/532
# Translated sentence 500/532
# Translated sentence 501/532
# Translated sentence 502/532
# Translated sentence 503/532
# Translated sentence 504/532
# Translated sentence 505/532
# Translated sentence 506/532
# Translated sentence 507/532
# Translated sentence 508/532
# Translated sentence 509/532
# Translated sentence 510/532
# Translated sentence 511/532
# Translated sentence 512/532
# Translated sentence 513/532
# Translated sentence 514/532
# Translated sentence 515/532
# Translated sentence 516/532
# Translated sentence 517/532
# Translated sentence 518/532
# Translated sentence 519/532
# Translated sentence 520/532
# Translated sentence 521/532
# Translated sentence 522/532
# Translated sentence 523/532
# Translated sentence 524/532
# Translated sentence 525/532
# Translated sentence 526/532
# Translated sentence 527/532
# Translated sentence 528/532
# Translated sentence 529/532
# Translated sentence 530/532
# Translated sentence 531/532
# Translated sentence 532/532
#
# Original and translated content saved to translated_document_full.txt

# %%
from docx import Document
from transformers import MarianMTModel, MarianTokenizer
from nltk.tokenize import sent_tokenize

# Ensure you have nltk punkt tokenizer downloaded
import nltk
try:
    sent_tokenize("example.")
except LookupError:
    nltk.download('punkt')

def translate_text(text, tokenizer, model):
    """Translates a single text string."""
    if not text:
        return ""
    try:
        input_ids = tokenizer.encode(text, return_tensors="pt", truncation=True, max_length=tokenizer.model_max_length)
        outputs = model.generate(input_ids)
        decoded_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
        return decoded_text
    except Exception as e:
        print(f"Translation error for text: '{text[:50]}...': {e}")
        return None

def translate_docx(input_docx_path, output_docx_path, source_lang, target_lang):
    """
    Translates the text content of a DOCX file and saves the translation to a new DOCX file.

    Args:
        input_docx_path (str): Path to the input DOCX file.
        output_docx_path (str): Path to save the translated DOCX file.
        source_lang (str): Source language code (e.g., 'en').
        target_lang (str): Target language code (e.g., 'ar').
    """
    try:
        document = Document(input_docx_path)
    except FileNotFoundError:
        print(f"Error: Input DOCX file not found at {input_docx_path}")
        return

    model_name = f"Helsinki-NLP/opus-mt-{source_lang}-{target_lang}"
    try:
        tokenizer = MarianTokenizer.from_pretrained(model_name)
        model = MarianMTModel.from_pretrained(model_name)
        print(f"Loaded model for {source_lang} to {target_lang}")
    except Exception as e:
        print(f"Error loading model: {e}")
        return

    translated_document = Document()

    for paragraph in document.paragraphs:
        original_text = paragraph.text
        if original_text.strip():
            translated_text = translate_text(original_text, tokenizer, model)
            if translated_text:
                translated_document.add_paragraph(translated_text)
            else:
                translated_document.add_paragraph(original_text) # Keep original if translation fails
        else:
            translated_document.add_paragraph("") # Preserve empty paragraphs

    translated_document.save(output_docx_path)
    print(f"Translated DOCX saved to {output_docx_path}")

def translate_docx_sentences(input_docx_path, output_docx_path, source_lang, target_lang):
    """
    Translates the text content of a DOCX file sentence by sentence and saves
    the translation to a new DOCX file.

    Args:
        input_docx_path (str): Path to the input DOCX file.
        output_docx_path (str): Path to save the translated DOCX file.
        source_lang (str): Source language code (e.g., 'en').
        target_lang (str): Target language code (e.g., 'ar').
    """
    try:
        document = Document(input_docx_path)
    except FileNotFoundError:
        print(f"Error: Input DOCX file not found at {input_docx_path}")
        return

    model_name = f"Helsinki-NLP/opus-mt-{source_lang}-{target_lang}"
    try:
        tokenizer = MarianTokenizer.from_pretrained(model_name)
        model = MarianMTModel.from_pretrained(model_name)
        print(f"Loaded model for {source_lang} to {target_lang}")
    except Exception as e:
        print(f"Error loading model: {e}")
        return

    translated_document = Document()

    for paragraph in document.paragraphs:
        original_text = paragraph.text
        if original_text.strip():
            sentences = sent_tokenize(original_text)
            translated_sentences = [translate_text(sentence, tokenizer, model) for sentence in sentences]
            translated_paragraph = " ".join(translated_sentences)
            translated_document.add_paragraph(translated_paragraph)
        else:
            translated_document.add_paragraph("") # Preserve empty paragraphs

    translated_document.save(output_docx_path)
    print(f"Translated DOCX (sentence-by-sentence) saved to {output_docx_path}")

if __name__ == "__main__":
    input_docx = r"C:\Users\salsubhi1\PycharmProjects\Enigmatic Research\Dr.X Files\Stats.docx"  # Replace with your input DOCX file path
    output_docx = r"C:\Users\salsubhi1\PycharmProjects\Enigmatic Research\Translated_output\Stats_translated.docx" # Replace with your desired output DOCX file path
    source_language = "en"  # Replace with the source language of your DOCX file
    target_language = "ar"  # Replace with your desired target language

    # Example usage: Translate the entire text in the DOCX file paragraph by paragraph
    # translate_docx(input_docx, output_docx, source_language, target_language)

    # Example usage: Translate the text in the DOCX file sentence by sentence
    translate_docx_sentences(input_docx, output_docx, source_language, target_language)
# Out:
# C:\Users\salsubhi1\Anaconda3\envs\test\lib\site-packages\transformers\models\marian\tokenization_marian.py:175: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# Loaded model for en to ar
# Translated DOCX (sentence-by-sentence) saved to C:\Users\salsubhi1\PycharmProjects\Enigmatic Research\Dr.X Files\Stats_translated.docx

# %%
import pandas as pd
from transformers import MarianMTModel, MarianTokenizer
import re
from nltk.tokenize import sent_tokenize

# Ensure nltk punkt tokenizer is downloaded
import nltk
try:
    sent_tokenize("example.")
except LookupError:
    nltk.download('punkt')

def translate_text(text, tokenizer, model):
    """Translates a single text string."""
    if not text or pd.isna(text):
        return ""
    try:
        input_ids = tokenizer.encode(text, return_tensors="pt", truncation=True, max_length=tokenizer.model_max_length)
        outputs = model.generate(input_ids)
        decoded_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
        return decoded_text
    except Exception as e:
        print(f"Translation error for text: '{text[:50]}...': {e}")
        return None

def selectively_translate(text, tokenizer, model):
    """Attempts to translate only words, leaving numbers and short codes."""
    parts = re.split(r'(\b\w+\b)', text) # Split by word boundaries, keeping delimiters
    translated_parts = []
    for part in parts:
        if re.match(r'\b\w{3,}\b', part): # Translate words with 3 or more letters
            translated_parts.append(translate_text(part, tokenizer, model))
        else:
            translated_parts.append(part) # Keep numbers and short words as is
    return "".join(translated_parts)

def translate_csv_selective(input_csv_path, output_csv_path, source_lang, target_lang, column_to_translate):
    """Translates words (>= 3 letters) in a CSV column."""
    try:
        df = pd.read_csv(input_csv_path, encoding='utf-8')
    except FileNotFoundError:
        print(f"Error: Input CSV file not found at {input_csv_path}")
        return
    except Exception as e:
        print(f"Error reading CSV: {e}")
        return

    if column_to_translate not in df.columns:
        print(f"Error: Column '{column_to_translate}' not found in the CSV file.")
        return

    model_name = f"Helsinki-NLP/opus-mt-{source_lang}-{target_lang}"
    try:
        tokenizer = MarianTokenizer.from_pretrained(model_name)
        model = MarianMTModel.from_pretrained(model_name)
        print(f"Loaded model for {source_lang} to {target_lang}")
    except Exception as e:
        print(f"Error loading model: {e}")
        return

    translated_column = []
    for index, row in df.iterrows():
        text_to_translate = row[column_to_translate]
        translated_text = selectively_translate(str(text_to_translate), tokenizer, model)
        translated_column.append(translated_text)

    df[f"{column_to_translate}_{target_lang}"] = translated_column
    df.to_csv(output_csv_path, index=False, encoding='utf-8')
    print(f"Selectively translated CSV saved to {output_csv_path}")

if __name__ == "__main__":
    input_csv = r"C:\Users\salsubhi1\PycharmProjects\Enigmatic Research\excel_chunks_text.csv"
    output_csv = r"C:\Users\salsubhi1\PycharmProjects\Enigmatic Research\Translated_output\excel_chunks_text_translated_selective.csv"
    source_language = "en"
    target_language = "ar"
    text_column = "text"

    translate_csv_selective(input_csv, output_csv, source_language, target_language, text_column)
# Out:
# C:\Users\salsubhi1\Anaconda3\envs\test\lib\site-packages\transformers\models\marian\tokenization_marian.py:175: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# Loaded model for en to ar
# Selectively translated CSV saved to C:\Users\salsubhi1\PycharmProjects\Enigmatic Research\Translated_output\excel_chunks_text_translated_selective.csv
